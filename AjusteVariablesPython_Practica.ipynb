# %% [markdown]
# # Probabilidad y Estadística con Python

# %% [markdown]
# ## ¿Qué es la Estadística?
#
# La estadística suele ser definida como la ciencia de aprender de los datos o como la ciencia de obtener conclusiones en la presencia de incertidumbre. Se relaciona principalmente con la recolección, análisis e interpretación de datos, así como también con la efectiva comunicación y presentación de los resultados basados en esos datos. Como por datos entendemos a cualquier clase de información grabada, la estadística juego un rol importante en muchas disciplinas científicas.
#
# La estadística suele ser dividida en dos grandes ramas:
#
# La estadística descriptiva: La cual se dedica a recolectar, ordenar, analizar y representar a un conjunto de datos, con el fin de describir apropiadamente las características de este. Calcula los parámetros estadísticos que describen el conjunto estudiado. Algunas de las herramientas que utiliza son gráficos, medidas de frecuencias, medidas de centralización, medidas de posición, medidas de dispersión, entre otras.
#
# La estadistica inferencial: La cual estudia cómo sacar conclusiones generales para toda la población a partir del estudio de una muestra, y el grado de fiabilidad o significación de los resultados obtenidos. Sus principales herramientas son el muestreo, la estimación de parámetros y el contraste de hipótesis.

# %% [markdown]
# ## Conceptos básicos de la estadística descriptiva
#
# En *[estadística descriptiva](https://es.wikipedia.org/wiki/Estad%C3%ADstica_descriptiva)* se utilizan distintas medidas para intentar describir las propiedades de nuestros datos, algunos de los conceptos básicos, son:
#
# * **Media aritmética**: La [media aritmética](https://es.wikipedia.org/wiki/Media_aritm%C3%A9tica) es el valor obtenido al sumar todos los *[datos](https://es.wikipedia.org/wiki/Dato)* y dividir el resultado entre el número total elementos. Se suele representar con la letra griega $\mu$. Si tenemos una [muestra](https://es.wikipedia.org/wiki/Muestra_estad%C3%ADstica) de $n$ valores, $x_i$, la *media aritmética*, $\mu$, es la suma de los valores divididos por el numero de elementos; en otras palabras:
# $$\mu = \frac{1}{n} \sum_{i}x_i$$
#
#
# * **Desviación respecto a la media**: La desviación respecto a la media es la diferencia en valor absoluto entre cada valor de la variable estadística y la media aritmética.
# $$D_i = |x_i - \mu|$$
#
#
# * **Varianza**: La [varianza](https://es.wikipedia.org/wiki/Varianza) es la media aritmética del cuadrado de las desviaciones respecto a la media de una distribución estadística. La varianza intenta describir la dispersión de los *[datos](https://es.wikipedia.org/wiki/Dato)*. Se representa como $\sigma^2$.
# $$\sigma^2 = \frac{\sum\limits_{i=1}^n(x_i - \mu)^2}{n} $$
#
#
# * **Desviación típica**: La [desviación típica](https://es.wikipedia.org/wiki/Desviaci%C3%B3n_t%C3%ADpica) es la raíz cuadrada de la varianza. Se representa con la letra griega $\sigma$.
# $$\sigma = \sqrt{\frac{\sum\limits_{i=1}^n(x_i - \mu)^2}{n}} $$
#
#
# * **Moda**: La <a href="https://es.wikipedia.org/wiki/Moda_(estad%C3%ADstica)">moda</a> es el valor que tiene mayor frecuencia absoluta. Se representa con $M_0$
#
#
# * **Mediana**: La <a href="https://es.wikipedia.org/wiki/Mediana_(estad%C3%ADstica)">mediana</a> es el valor que ocupa el lugar central de todos los datos cuando éstos están ordenados de menor a mayor. Se representa con $\widetilde{x}$.

# %% [markdown]
# ### Ejemplos en Python
#
# Calcular los principales indicadores de la *[estadística descriptiva](https://es.wikipedia.org/wiki/Estad%C3%ADstica_descriptiva)* con [Python](http://python.org/) es muy fácil!.

# %%
# Ejemplos de estadistica descriptiva con python

import numpy as np # importando numpy
from scipy import stats # importando scipy.stats
import pandas as pd # importando pandas

np.random.seed(2131982) # para poder replicar el random

# %%
datos = np.random.randn(5, 4) # datos normalmente distribuidos
datos
# Out:
# array([[ 0.46038022, -1.08942528, -0.62681496, -0.63329028],
#        [-0.1074033 , -0.88138082, -0.34466623, -0.28320214],
#        [ 0.94051171,  0.86693793,  1.20947882, -0.16894118],
#        [-0.12790177, -0.58099931, -0.46188426, -0.18148302],
#        [-0.76959435, -1.37414587,  1.37696874, -0.18040537]])

# %%
# media arítmetica
datos.mean() # Calcula la media aritmetica de
# Out:
# -0.14786303590303568

# %%
np.mean(datos) # Mismo resultado desde la funcion de numpy
# Out:
# -0.14786303590303568

# %%
datos.mean(axis=1) # media aritmetica de cada fila
# Out:
# array([-0.47228757, -0.40416312,  0.71199682, -0.33806709, -0.23679421])

# %%
datos.mean(axis=0) # media aritmetica de cada columna
# Out:
# array([ 0.0791985 , -0.61180267,  0.23061642, -0.2894644 ])

# %%
# mediana
np.median(datos)
# Out:
# -0.23234258265023794

# %%
np.median(datos, 0) # media aritmetica de cada columna
# Out:
# array([-0.1074033 , -0.88138082, -0.34466623, -0.18148302])

# %%
 # Desviación típica
np.std(datos)
# Out:
# 0.73755354584071608

# %%
np.std(datos, 0) # Desviación típica de cada columna
# Out:
# array([ 0.58057213,  0.78352862,  0.87384108,  0.17682485])

# %%
# varianza
np.var(datos)
# Out:
# 0.54398523298221324

# %%
np.var(datos, 0) # varianza de cada columna
# Out:
# array([ 0.337064  ,  0.6139171 ,  0.76359823,  0.03126703])

# %%
# moda
stats.mode(datos) # Calcula la moda de cada columna
# el 2do array devuelve la frecuencia.
# Out:
# (array([[-0.76959435, -1.37414587, -0.62681496, -0.63329028]]),
#  array([[ 1.,  1.,  1.,  1.]]))

# %%
datos2 = np.array([1, 2, 3, 6, 6, 1, 2, 4, 2, 2, 6, 6, 8, 10, 6])
stats.mode(datos2) # aqui la moda es el 6 porque aparece 5 veces en el vector.
# Out:
# ModeResult(mode=array([6]), count=array([5]))

# %% [markdown]
# ## Practica :
# Generar un modelo que me permita simular el uso de recursos de los hospitales por cada una de las provincias, para ello obtener la informacion revisada en la practica de investigacion y tomar como ejemplo la practica de simulacion de atencion de paciente del COVID revisada en clase. Lo que se busca es poder generar graficos de uso de recursos:
#
# - Costos (Generar un aproximacion de cuanto se invierte para atender a un paciente con COVID)
# - Personal (Aproximacion del uso del personal por paciente, o el hospital)
# - Camas
# - Equipos/Insumos medicos (Obtener una aproximacion del uso de equipos medicos)
# - Pacientes (Informacion obtenida desde el ministerio de salud - validar con el porcentual del tipo de paciente [ninio 10%, adulto 30%, riesgo 60%]) - Hospitalizacion 80%, Otros 20%
#
#
# Para ello deberan generar un modelo lo mas cercano a la realidad, y con ayuda de la estadistica descriptiva ajustar los valores. Es importante tener como datos de entrada el dia y el numero de pacientes.
#
# Finalmente validar el modelo con lo la realidad del pais (Investigar en  base al tema el uso de los recursos publicos )

# %%
import simpy
import random
import matplotlib.pyplot as pp
import numpy as np

# %matplotlib inline

#PARAMETROS
HOSPITALES = 2
HOSPITAL_CAMA_A = 300
HOSPITAL_CAMA_B = 150
HOSPITAL_Personal_A = 387
HOSPITAL_Personal_B = 387
HOSPITAL_Equipos_A = 68 
HOSPITAL_Equipos_B = 48 
INFECTADOS = 1956
TASA_CRECIMIENTO = 321
DIAS_INTERNADO = 10
DIAS_Atencion_Personal = 10
DIAS_uso_equipo = 4
DIAS_SIMULACION = 20
costo_persona = 1200


#Diccionario para almacenar los resultados
persona_recuperadas={}
persona_fallecidas={}
ninios={}
adultos={}
ancianos={}
pacientes_atendidos_equipos=[]
pacientes_atendidos_camas=[]
pacientes_atendidos_personal=[]

class Hospital(object):
    #constructor
    def __init__(self, env, num_cama,num_personal,num_equipos, name):
            self.env = env
            self.num_cama = num_cama
            self.num_personal=num_personal
            self.num_equipos=num_equipos
            self.camas = simpy.Resource(env, num_cama)
            self.personal = simpy.Resource(env, num_personal)
            self.equipos = simpy.Resource(env, num_equipos)
            self.name = name
            
    def ingresar_paciente(self, paciente):
        yield self.env.timeout(random.randint(DIAS_INTERNADO-5, DIAS_INTERNADO+5))
        print("El paciente fue a una cama: ", paciente, " tiempo de salida: ", self.env.now, " hospital ", self.name)
    def uso_personal_paciente(self, paciente):
        yield self.env.timeout(random.randint(DIAS_Atencion_Personal-3, DIAS_Atencion_Personal+3))
        print("El paciente fue atendido por el personal: ", paciente, " tiempo de salida: ", self.env.now, " hospital ", self.name)
    def uso_equipo_paciente(self, paciente):
        yield self.env.timeout(random.randint(DIAS_uso_equipo-1, DIAS_uso_equipo+1))
        print("El paciente Recibio equipos: ", paciente, " tiempo de salida: ", self.env.now, " hospital ", self.name)
def llegada_paciente(env, hospital, paciente):
    arrive = env.now
    estado = random.randint(1,100)
    if (estado <= 10 and estado > 0):
        ninios[env.now] = ninios[env.now] + 1 if env.now in ninios else  1
        
        with hospital.camas.request() as cama:
            dias_esperando = random.randint(1,3) #Numero de dias maximo que puede esperar sin ser asignado a una cama dentro del hospital
            requerimiento = yield cama | env.timeout(dias_esperando) #Asignar un tiempo de espera
            wait = env.now - arrive
            if cama in requerimiento:
                print("Al paciente: ", paciente, " se le asigna una CAMA ", " hospital " , hospital.name)
                yield env.process(hospital.ingresar_paciente(paciente))
                arrive2 = env.now
                pacientes_atendidos_camas.append(1)
                with hospital.personal.request() as persona:
                    dias_esperando_personal = random.randint(1,2)
                    requerimiento2 = yield persona | env.timeout(dias_esperando_personal)
                    wait2 = env.now - arrive2
                    if persona in requerimiento2:
                        print("Al paciente: ", paciente, " recive atencion del personal ", " hospital " , hospital.name)
                        yield env.process(hospital.uso_personal_paciente(paciente))
                        arrive3 = env.now
                        pacientes_atendidos_personal.append(1)
                        with hospital.equipos.request() as equipo:
                            dias_esperando_equipo = random.randint(1,2)
                            requerimiento3 = yield equipo | env.timeout(dias_esperando_equipo)
                            wait3 = env.now - arrive3
                            if equipo in requerimiento3:
                                print("Al paciente: ", paciente, " recive equipos ", " hospital " , hospital.name)
                                yield env.process(hospital.uso_equipo_paciente(paciente))
                                estado = random.randint(1,100)
                                pacientes_atendidos_equipos.append(1)
                                if (estado < 8) :
                                    persona_fallecidas[env.now] = persona_fallecidas[env.now] + 1 if env.now in persona_fallecidas else  1
                                else:
                                    persona_recuperadas[env.now] = persona_recuperadas[env.now] + 1 if env.now in persona_recuperadas else 1 
                            else:
                                print("El paciente " , paciente, " en el hospital ", hospital.name, " espero ", wait3 , " dias y fallece no hubo Equipo")
                                persona_fallecidas[env.now] = persona_fallecidas[env.now] + 1 if env.now in persona_fallecidas else  1
                        
                    else:
                        print("El paciente " , paciente, " en el hospital ", hospital.name, " espero ", wait2 , " dias y fallece no hubo personal")
                        persona_fallecidas[env.now] = persona_fallecidas[env.now] + 1 if env.now in persona_fallecidas else  1
                        
            else:
                print("El paciente " , paciente, " en el hospital ", hospital.name, " espero ", wait , " dias y fallece no hay camas")
                persona_fallecidas[env.now] = persona_fallecidas[env.now] + 1 if env.now in persona_fallecidas else  1        
    
    if (estado <= 30 and estado >= 11):
        adultos[env.now] = adultos[env.now] + 1 if env.now in adultos else  1
        
        with hospital.camas.request() as cama:
            dias_esperando = random.randint(1,3) #Numero de dias maximo que puede esperar sin ser asignado a una cama dentro del hospital
            requerimiento = yield cama | env.timeout(dias_esperando) #Asignar un tiempo de espera
            wait = env.now - arrive
            if cama in requerimiento:
                print("Al paciente: ", paciente, " se le asigna una CAMA ", " hospital " , hospital.name)
                yield env.process(hospital.ingresar_paciente(paciente))
                arrive2 = env.now
                pacientes_atendidos_camas.append(1)
                with hospital.personal.request() as persona:
                    dias_esperando_personal = random.randint(1,2)
                    requerimiento2 = yield persona | env.timeout(dias_esperando_personal)
                    wait2 = env.now - arrive2
                    if persona in requerimiento2:
                        print("Al paciente: ", paciente, " recive atencion del personal ", " hospital " , hospital.name)
                        yield env.process(hospital.uso_personal_paciente(paciente))
                        arrive3 = env.now
                        pacientes_atendidos_personal.append(1)
                        with hospital.equipos.request() as equipo:
                            dias_esperando_equipo = random.randint(1,2)
                            requerimiento3 = yield equipo | env.timeout(dias_esperando_equipo)
                            wait3 = env.now - arrive3
                            if equipo in requerimiento3:
                                print("Al paciente: ", paciente, " recive equipos ", " hospital " , hospital.name)
                                yield env.process(hospital.uso_equipo_paciente(paciente))
                                estado = random.randint(1,100)
                                pacientes_atendidos_equipos.append(1)
                                if (estado < 8) :
                                    persona_fallecidas[env.now] = persona_fallecidas[env.now] + 1 if env.now in persona_fallecidas else  1
                                else:
                                    persona_recuperadas[env.now] = persona_recuperadas[env.now] + 1 if env.now in persona_recuperadas else 1 
                            else:
                                print("El paciente " , paciente, " en el hospital ", hospital.name, " espero ", wait3 , " dias y fallece no hubo Equipo")
                                persona_fallecidas[env.now] = persona_fallecidas[env.now] + 1 if env.now in persona_fallecidas else  1
                        
                    else:
                        print("El paciente " , paciente, " en el hospital ", hospital.name, " espero ", wait2 , " dias y fallece no hubo personal")
                        persona_fallecidas[env.now] = persona_fallecidas[env.now] + 1 if env.now in persona_fallecidas else  1
                        
            else:
                print("El paciente " , paciente, " en el hospital ", hospital.name, " espero ", wait , " dias y fallece no hay camas")
                persona_fallecidas[env.now] = persona_fallecidas[env.now] + 1 if env.now in persona_fallecidas else  1        

        
        
        
        
    if (estado <= 100 and estado >= 31):
        ancianos[env.now] = ancianos[env.now] + 1 if env.now in ancianos else  1
        
        with hospital.camas.request() as cama:
            dias_esperando = random.randint(1,3) #Numero de dias maximo que puede esperar sin ser asignado a una cama dentro del hospital
            requerimiento = yield cama | env.timeout(dias_esperando) #Asignar un tiempo de espera
            wait = env.now - arrive
            if cama in requerimiento:
                print("Al paciente: ", paciente, " se le asigna una CAMA ", " hospital " , hospital.name)
                yield env.process(hospital.ingresar_paciente(paciente))
                arrive2 = env.now
                pacientes_atendidos_camas.append(1)
                with hospital.personal.request() as persona:
                    dias_esperando_personal = random.randint(1,2)
                    requerimiento2 = yield persona | env.timeout(dias_esperando_personal)
                    wait2 = env.now - arrive2
                    if persona in requerimiento2:
                        print("Al paciente: ", paciente, " recive atencion del personal ", " hospital " , hospital.name)
                        yield env.process(hospital.uso_personal_paciente(paciente))
                        arrive3 = env.now
                        pacientes_atendidos_personal.append(1)
                        with hospital.equipos.request() as equipo:
                            dias_esperando_equipo = random.randint(1,2)
                            requerimiento3 = yield equipo | env.timeout(dias_esperando_equipo)
                            wait3 = env.now - arrive3
                            if equipo in requerimiento3:
                                print("Al paciente: ", paciente, " recive equipos ", " hospital " , hospital.name)
                                yield env.process(hospital.uso_equipo_paciente(paciente))
                                estado = random.randint(1,100)
                                pacientes_atendidos_equipos.append(1)
                                if (estado < 8) :
                                    persona_fallecidas[env.now] = persona_fallecidas[env.now] + 1 if env.now in persona_fallecidas else  1
                                else:
                                    persona_recuperadas[env.now] = persona_recuperadas[env.now] + 1 if env.now in persona_recuperadas else 1 
                            else:
                                print("El paciente " , paciente, " en el hospital ", hospital.name, " espero ", wait3 , " dias y fallece no hubo Equipo")
                                persona_fallecidas[env.now] = persona_fallecidas[env.now] + 1 if env.now in persona_fallecidas else  1
                        
                    else:
                        print("El paciente " , paciente, " en el hospital ", hospital.name, " espero ", wait2 , " dias y fallece no hubo personal")
                        persona_fallecidas[env.now] = persona_fallecidas[env.now] + 1 if env.now in persona_fallecidas else  1
                        
            else:
                print("El paciente " , paciente, " en el hospital ", hospital.name, " espero ", wait , " dias y fallece no hay camas")
                persona_fallecidas[env.now] = persona_fallecidas[env.now] + 1 if env.now in persona_fallecidas else  1        

        
        
def ejecutar(env, tasa_crecimiento, infectados):
    hospitalA = Hospital(env, HOSPITAL_CAMA_A,HOSPITAL_Personal_A,HOSPITAL_Equipos_A, "A")
    hospitalB = Hospital(env, HOSPITAL_CAMA_B,HOSPITAL_Personal_B,HOSPITAL_Equipos_B, "B")
    for i in range(infectados):
        asignar_hospital(env, hospitalA, hospitalB, i)
    paciente = infectados
    while True:
        yield env.timeout(1)
        for i in range(tasa_crecimiento):
            paciente += 1
            asignar_hospital(env, hospitalA, hospitalB, paciente)
                
def asignar_hospital(env, hospitalA, hospitalB, paciente):
    hosp_esc = random.randint(1,2)
    if (hosp_esc == 1):
        print("Llega paciente nuevo : ", paciente, " hospital A tiempo ", env.now)
        env.process(llegada_paciente(env, hospitalA, paciente))
    else:
        print("Llega paciente nuevo : ", paciente, " hospital B tiempo ", env.now)
        env.process(llegada_paciente(env, hospitalB, paciente))
    
print("Simulacion COVID 19")
env=simpy.Environment()
env.process(ejecutar(env,TASA_CRECIMIENTO, INFECTADOS))
env.run(until=DIAS_SIMULACION)

print("Resultados pacientes :")
print("Recuperados: ")
print(persona_recuperadas)
print("Fallecidos: ")
print(persona_fallecidas)

datos=sorted(persona_recuperadas.items()) # Ordenamos los datos
x, y =zip(*datos) # Obtener x(tiempo - clave) y el y(Numero de vehiculos atendidos - valor)
pp.plot(x,y,linewidth=2,color='red') # Dibujamos las lineas
pp.scatter(x,y,color='blue') # Dibujamos los puntos (x,y)
pp.title("Dias  / Personas Recuperadas")
pp.grid(True) # Generamos una cuadricula
pp.show() # Mostramos el grafico

if (persona_fallecidas):
    datos=sorted(persona_fallecidas.items()) # Ordenamos los datos
    x, y =zip(*datos) # Obtener x(tiempo - clave) y el y(Numero de vehiculos atendidos - valor)
    pp.plot(x,y,linewidth=2,color='red') #Dibujamos las lineas
    pp.scatter(x,y,color='blue') # Dibujamos los puntos (x,y)
    pp.title("Personas Fallecidas  / dias de hospitalizacion")
    pp.grid(True) #Generamos una cuadricula
    pp.show() #Mostramos el grafico
if (ninios):
    datos=sorted(ninios.items()) # Ordenamos los datos
    x, y =zip(*datos) # Obtener x(tiempo - clave) y el y(Numero de vehiculos atendidos - valor)
    pp.plot(x,y,linewidth=2,color='red') #Dibujamos las lineas
    pp.scatter(x,y,color='blue') # Dibujamos los puntos (x,y)
    pp.title("ninios  / dias de hospitalizacion")
    pp.grid(True) #Generamos una cuadricula
    pp.show() #Mostramos el grafico
if (adultos):
    datos=sorted(adultos.items()) # Ordenamos los datos
    x, y =zip(*datos) # Obtener x(tiempo - clave) y el y(Numero de vehiculos atendidos - valor)
    pp.plot(x,y,linewidth=2,color='red') #Dibujamos las lineas
    pp.scatter(x,y,color='blue') # Dibujamos los puntos (x,y)
    pp.title("adultos  / dias de hospitalizacion")
    pp.grid(True) #Generamos una cuadricula
    pp.show() #Mostramos el grafico
if (ancianos):
    datos=sorted(ancianos.items()) # Ordenamos los datos
    x, y =zip(*datos) # Obtener x(tiempo - clave) y el y(Numero de vehiculos atendidos - valor)
    pp.plot(x,y,linewidth=2,color='red') #Dibujamos las lineas
    pp.scatter(x,y,color='blue') # Dibujamos los puntos (x,y)
    pp.title("ancianos / dias de hospitalizacion")
    pp.grid(True) #Generamos una cuadricula
    pp.show() #Mostramos el grafico
# Out:
# Simulacion COVID 19
# Llega paciente nuevo :  0  hospital B tiempo  0
# Llega paciente nuevo :  1  hospital A tiempo  0
# Llega paciente nuevo :  2  hospital A tiempo  0
# Llega paciente nuevo :  3  hospital A tiempo  0
# Llega paciente nuevo :  4  hospital B tiempo  0
# Llega paciente nuevo :  5  hospital B tiempo  0
# Llega paciente nuevo :  6  hospital B tiempo  0
# Llega paciente nuevo :  7  hospital B tiempo  0
# Llega paciente nuevo :  8  hospital B tiempo  0
# Llega paciente nuevo :  9  hospital B tiempo  0
# Llega paciente nuevo :  10  hospital A tiempo  0
# Llega paciente nuevo :  11  hospital B tiempo  0
# Llega paciente nuevo :  12  hospital A tiempo  0
# Llega paciente nuevo :  13  hospital A tiempo  0
# Llega paciente nuevo :  14  hospital B tiempo  0
# Llega paciente nuevo :  15  hospital B tiempo  0
# Llega paciente nuevo :  16  hospital B tiempo  0
# Llega paciente nuevo :  17  hospital A tiempo  0
# Llega paciente nuevo :  18  hospital A tiempo  0
# Llega paciente nuevo :  19  hospital B tiempo  0
# Llega paciente nuevo :  20  hospital B tiempo  0
# Llega paciente nuevo :  21  hospital A tiempo  0
# Llega paciente nuevo :  22  hospital B tiempo  0
# Llega paciente nuevo :  23  hospital B tiempo  0
# Llega paciente nuevo :  24  hospital A tiempo  0
# Llega paciente nuevo :  25  hospital B tiempo  0
# Llega paciente nuevo :  26  hospital A tiempo  0
# Llega paciente nuevo :  27  hospital A tiempo  0
# Llega paciente nuevo :  28  hospital B tiempo  0
# Llega paciente nuevo :  29  hospital B tiempo  0
# Llega paciente nuevo :  30  hospital B tiempo  0
# Llega paciente nuevo :  31  hospital B tiempo  0
# Llega paciente nuevo :  32  hospital A tiempo  0
# Llega paciente nuevo :  33  hospital A tiempo  0
# Llega paciente nuevo :  34  hospital A tiempo  0
# Llega paciente nuevo :  35  hospital A tiempo  0
# Llega paciente nuevo :  36  hospital A tiempo  0
# Llega paciente nuevo :  37  hospital B tiempo  0
# Llega paciente nuevo :  38  hospital B tiempo  0
# Llega paciente nuevo :  39  hospital A tiempo  0
# Llega paciente nuevo :  40  hospital B tiempo  0
# Llega paciente nuevo :  41  hospital B tiempo  0
# Llega paciente nuevo :  42  hospital B tiempo  0
# Llega paciente nuevo :  43  hospital B tiempo  0
# Llega paciente nuevo :  44  hospital A tiempo  0
# Llega paciente nuevo :  45  hospital B tiempo  0
# Llega paciente nuevo :  46  hospital A tiempo  0
# Llega paciente nuevo :  47  hospital B tiempo  0
# Llega paciente nuevo :  48  hospital A tiempo  0
# Llega paciente nuevo :  49  hospital A tiempo  0
# Llega paciente nuevo :  50  hospital B tiempo  0
# Llega paciente nuevo :  51  hospital B tiempo  0
# Llega paciente nuevo :  52  hospital B tiempo  0
# Llega paciente nuevo :  53  hospital B tiempo  0
# Llega paciente nuevo :  54  hospital B tiempo  0
# Llega paciente nuevo :  55  hospital A tiempo  0
# Llega paciente nuevo :  56  hospital B tiempo  0
# Llega paciente nuevo :  57  hospital B tiempo  0
# Llega paciente nuevo :  58  hospital A tiempo  0
# Llega paciente nuevo :  59  hospital A tiempo  0
# Llega paciente nuevo :  60  hospital A tiempo  0
# Llega paciente nuevo :  61  hospital A tiempo  0
# Llega paciente nuevo :  62  hospital B tiempo  0
# Llega paciente nuevo :  63  hospital B tiempo  0
# Llega paciente nuevo :  64  hospital A tiempo  0
# Llega paciente nuevo :  65  hospital A tiempo  0
# Llega paciente nuevo :  66  hospital A tiempo  0
# Llega paciente nuevo :  67  hospital A tiempo  0
# Llega paciente nuevo :  68  hospital B tiempo  0
# Llega paciente nuevo :  69  hospital A tiempo  0
# Llega paciente nuevo :  70  hospital B tiempo  0
# Llega paciente nuevo :  71  hospital B tiempo  0
# Llega paciente nuevo :  72  hospital A tiempo  0
# Llega paciente nuevo :  73  hospital A tiempo  0
# Llega paciente nuevo :  74  hospital B tiempo  0
# Llega paciente nuevo :  75  hospital A tiempo  0
# Llega paciente nuevo :  76  hospital B tiempo  0
# Llega paciente nuevo :  77  hospital A tiempo  0
# Llega paciente nuevo :  78  hospital A tiempo  0
# Llega paciente nuevo :  79  hospital A tiempo  0
# Llega paciente nuevo :  80  hospital A tiempo  0
# Llega paciente nuevo :  81  hospital B tiempo  0
# Llega paciente nuevo :  82  hospital A tiempo  0
# Llega paciente nuevo :  83  hospital B tiempo  0
# Llega paciente nuevo :  84  hospital A tiempo  0
# Llega paciente nuevo :  85  hospital B tiempo  0
# Llega paciente nuevo :  86  hospital A tiempo  0
# Llega paciente nuevo :  87  hospital B tiempo  0
# Llega paciente nuevo :  88  hospital A tiempo  0
# Llega paciente nuevo :  89  hospital A tiempo  0
# Llega paciente nuevo :  90  hospital B tiempo  0
# Llega paciente nuevo :  91  hospital B tiempo  0
# Llega paciente nuevo :  92  hospital B tiempo  0
# Llega paciente nuevo :  93  hospital A tiempo  0
# Llega paciente nuevo :  94  hospital B tiempo  0
# Llega paciente nuevo :  95  hospital B tiempo  0
# Llega paciente nuevo :  96  hospital B tiempo  0
# Llega paciente nuevo :  97  hospital B tiempo  0
# Llega paciente nuevo :  98  hospital B tiempo  0
# Llega paciente nuevo :  99  hospital B tiempo  0
# Llega paciente nuevo :  100  hospital B tiempo  0
# Llega paciente nuevo :  101  hospital B tiempo  0
# Llega paciente nuevo :  102  hospital B tiempo  0
# Llega paciente nuevo :  103  hospital A tiempo  0
# Llega paciente nuevo :  104  hospital A tiempo  0
# Llega paciente nuevo :  105  hospital B tiempo  0
# Llega paciente nuevo :  106  hospital A tiempo  0
# Llega paciente nuevo :  107  hospital B tiempo  0
# Llega paciente nuevo :  108  hospital A tiempo  0
# Llega paciente nuevo :  109  hospital B tiempo  0
# Llega paciente nuevo :  110  hospital A tiempo  0
# Llega paciente nuevo :  111  hospital B tiempo  0
# Llega paciente nuevo :  112  hospital B tiempo  0
# Llega paciente nuevo :  113  hospital A tiempo  0
# Llega paciente nuevo :  114  hospital B tiempo  0
# Llega paciente nuevo :  115  hospital A tiempo  0
# Llega paciente nuevo :  116  hospital B tiempo  0
# Llega paciente nuevo :  117  hospital A tiempo  0
# Llega paciente nuevo :  118  hospital A tiempo  0
# Llega paciente nuevo :  119  hospital B tiempo  0
# Llega paciente nuevo :  120  hospital A tiempo  0
# Llega paciente nuevo :  121  hospital A tiempo  0
# Llega paciente nuevo :  122  hospital A tiempo  0
# Llega paciente nuevo :  123  hospital A tiempo  0
# Llega paciente nuevo :  124  hospital B tiempo  0
# Llega paciente nuevo :  125  hospital B tiempo  0
# Llega paciente nuevo :  126  hospital A tiempo  0
# Llega paciente nuevo :  127  hospital A tiempo  0
# Llega paciente nuevo :  128  hospital A tiempo  0
# Llega paciente nuevo :  129  hospital A tiempo  0
# Llega paciente nuevo :  130  hospital A tiempo  0
# Llega paciente nuevo :  131  hospital A tiempo  0
# Llega paciente nuevo :  132  hospital A tiempo  0
# Llega paciente nuevo :  133  hospital A tiempo  0
# Llega paciente nuevo :  134  hospital A tiempo  0
# Llega paciente nuevo :  135  hospital A tiempo  0
# Llega paciente nuevo :  136  hospital B tiempo  0
# Llega paciente nuevo :  137  hospital B tiempo  0
# Llega paciente nuevo :  138  hospital A tiempo  0
# Llega paciente nuevo :  139  hospital B tiempo  0
# Llega paciente nuevo :  140  hospital A tiempo  0
# Llega paciente nuevo :  141  hospital B tiempo  0
# Llega paciente nuevo :  142  hospital B tiempo  0
# Llega paciente nuevo :  143  hospital B tiempo  0
# Llega paciente nuevo :  144  hospital B tiempo  0
# Llega paciente nuevo :  145  hospital B tiempo  0
# Llega paciente nuevo :  146  hospital A tiempo  0
# Llega paciente nuevo :  147  hospital A tiempo  0
# Llega paciente nuevo :  148  hospital B tiempo  0
# Llega paciente nuevo :  149  hospital B tiempo  0
# Llega paciente nuevo :  150  hospital A tiempo  0
# Llega paciente nuevo :  151  hospital A tiempo  0
# Llega paciente nuevo :  152  hospital B tiempo  0
# Llega paciente nuevo :  153  hospital A tiempo  0
# Llega paciente nuevo :  154  hospital A tiempo  0
# Llega paciente nuevo :  155  hospital B tiempo  0
# Llega paciente nuevo :  156  hospital B tiempo  0
# Llega paciente nuevo :  157  hospital B tiempo  0
# Llega paciente nuevo :  158  hospital A tiempo  0
# Llega paciente nuevo :  159  hospital B tiempo  0
# Llega paciente nuevo :  160  hospital B tiempo  0
# Llega paciente nuevo :  161  hospital A tiempo  0
# Llega paciente nuevo :  162  hospital B tiempo  0
# Llega paciente nuevo :  163  hospital B tiempo  0
# Llega paciente nuevo :  164  hospital B tiempo  0
# Llega paciente nuevo :  165  hospital A tiempo  0
# Llega paciente nuevo :  166  hospital B tiempo  0
# Llega paciente nuevo :  167  hospital A tiempo  0
# Llega paciente nuevo :  168  hospital A tiempo  0
# Llega paciente nuevo :  169  hospital A tiempo  0
# Llega paciente nuevo :  170  hospital A tiempo  0
# Llega paciente nuevo :  171  hospital B tiempo  0
# Llega paciente nuevo :  172  hospital B tiempo  0
# Llega paciente nuevo :  173  hospital B tiempo  0
# Llega paciente nuevo :  174  hospital A tiempo  0
# Llega paciente nuevo :  175  hospital A tiempo  0
# Llega paciente nuevo :  176  hospital A tiempo  0
# Llega paciente nuevo :  177  hospital B tiempo  0
# Llega paciente nuevo :  178  hospital A tiempo  0
# Llega paciente nuevo :  179  hospital A tiempo  0
# Llega paciente nuevo :  180  hospital B tiempo  0
# Llega paciente nuevo :  181  hospital A tiempo  0
# Llega paciente nuevo :  182  hospital A tiempo  0
# Llega paciente nuevo :  183  hospital A tiempo  0
# Llega paciente nuevo :  184  hospital A tiempo  0
# Llega paciente nuevo :  185  hospital B tiempo  0
# Llega paciente nuevo :  186  hospital A tiempo  0
# Llega paciente nuevo :  187  hospital B tiempo  0
# Llega paciente nuevo :  188  hospital A tiempo  0
# Llega paciente nuevo :  189  hospital B tiempo  0
# Llega paciente nuevo :  190  hospital A tiempo  0
# Llega paciente nuevo :  191  hospital B tiempo  0
# Llega paciente nuevo :  192  hospital A tiempo  0
# Llega paciente nuevo :  193  hospital B tiempo  0
# Llega paciente nuevo :  194  hospital A tiempo  0
# Llega paciente nuevo :  195  hospital B tiempo  0
# Llega paciente nuevo :  196  hospital B tiempo  0
# Llega paciente nuevo :  197  hospital B tiempo  0
# Llega paciente nuevo :  198  hospital B tiempo  0
# Llega paciente nuevo :  199  hospital B tiempo  0
# Llega paciente nuevo :  200  hospital B tiempo  0
# Llega paciente nuevo :  201  hospital A tiempo  0
# Llega paciente nuevo :  202  hospital A tiempo  0
# Llega paciente nuevo :  203  hospital B tiempo  0
# Llega paciente nuevo :  204  hospital A tiempo  0
# Llega paciente nuevo :  205  hospital B tiempo  0
# Llega paciente nuevo :  206  hospital B tiempo  0
# Llega paciente nuevo :  207  hospital B tiempo  0
# Llega paciente nuevo :  208  hospital A tiempo  0
# Llega paciente nuevo :  209  hospital A tiempo  0
# Llega paciente nuevo :  210  hospital A tiempo  0
# Llega paciente nuevo :  211  hospital A tiempo  0
# Llega paciente nuevo :  212  hospital B tiempo  0
# Llega paciente nuevo :  213  hospital A tiempo  0
# Llega paciente nuevo :  214  hospital B tiempo  0
# Llega paciente nuevo :  215  hospital B tiempo  0
# Llega paciente nuevo :  216  hospital B tiempo  0
# Llega paciente nuevo :  217  hospital A tiempo  0
# Llega paciente nuevo :  218  hospital B tiempo  0
# Llega paciente nuevo :  219  hospital A tiempo  0
# Llega paciente nuevo :  220  hospital B tiempo  0
# Llega paciente nuevo :  221  hospital A tiempo  0
# Llega paciente nuevo :  222  hospital A tiempo  0
# Llega paciente nuevo :  223  hospital B tiempo  0
# Llega paciente nuevo :  224  hospital A tiempo  0
# Llega paciente nuevo :  225  hospital B tiempo  0
# Llega paciente nuevo :  226  hospital A tiempo  0
# Llega paciente nuevo :  227  hospital B tiempo  0
# Llega paciente nuevo :  228  hospital B tiempo  0
# Llega paciente nuevo :  229  hospital B tiempo  0
# Llega paciente nuevo :  230  hospital A tiempo  0
# Llega paciente nuevo :  231  hospital A tiempo  0
# Llega paciente nuevo :  232  hospital A tiempo  0
# Llega paciente nuevo :  233  hospital B tiempo  0
# Llega paciente nuevo :  234  hospital B tiempo  0
# Llega paciente nuevo :  235  hospital A tiempo  0
# Llega paciente nuevo :  236  hospital A tiempo  0
# Llega paciente nuevo :  237  hospital B tiempo  0
# Llega paciente nuevo :  238  hospital B tiempo  0
# Llega paciente nuevo :  239  hospital B tiempo  0
# Llega paciente nuevo :  240  hospital B tiempo  0
# Llega paciente nuevo :  241  hospital B tiempo  0
# Llega paciente nuevo :  242  hospital A tiempo  0
# Llega paciente nuevo :  243  hospital B tiempo  0
# Llega paciente nuevo :  244  hospital B tiempo  0
# Llega paciente nuevo :  245  hospital B tiempo  0
# Llega paciente nuevo :  246  hospital B tiempo  0
# Llega paciente nuevo :  247  hospital B tiempo  0
# Llega paciente nuevo :  248  hospital B tiempo  0
# Llega paciente nuevo :  249  hospital A tiempo  0
# Llega paciente nuevo :  250  hospital B tiempo  0
# Llega paciente nuevo :  251  hospital B tiempo  0
# Llega paciente nuevo :  252  hospital B tiempo  0
# Llega paciente nuevo :  253  hospital B tiempo  0
# Llega paciente nuevo :  254  hospital B tiempo  0
# Llega paciente nuevo :  255  hospital A tiempo  0
# Llega paciente nuevo :  256  hospital A tiempo  0
# Llega paciente nuevo :  257  hospital A tiempo  0
# Llega paciente nuevo :  258  hospital B tiempo  0
# Llega paciente nuevo :  259  hospital B tiempo  0
# Llega paciente nuevo :  260  hospital B tiempo  0
# Llega paciente nuevo :  261  hospital A tiempo  0
# Llega paciente nuevo :  262  hospital A tiempo  0
# Llega paciente nuevo :  263  hospital A tiempo  0
# Llega paciente nuevo :  264  hospital A tiempo  0
# Llega paciente nuevo :  265  hospital B tiempo  0
# Llega paciente nuevo :  266  hospital A tiempo  0
# Llega paciente nuevo :  267  hospital B tiempo  0
# Llega paciente nuevo :  268  hospital A tiempo  0
# Llega paciente nuevo :  269  hospital B tiempo  0
# Llega paciente nuevo :  270  hospital A tiempo  0
# Llega paciente nuevo :  271  hospital B tiempo  0
# Llega paciente nuevo :  272  hospital A tiempo  0
# Llega paciente nuevo :  273  hospital B tiempo  0
# Llega paciente nuevo :  274  hospital A tiempo  0
# Llega paciente nuevo :  275  hospital B tiempo  0
# Llega paciente nuevo :  276  hospital B tiempo  0
# Llega paciente nuevo :  277  hospital A tiempo  0
# Llega paciente nuevo :  278  hospital B tiempo  0
# Llega paciente nuevo :  279  hospital B tiempo  0
# Llega paciente nuevo :  280  hospital B tiempo  0
# Llega paciente nuevo :  281  hospital A tiempo  0
# Llega paciente nuevo :  282  hospital B tiempo  0
# Llega paciente nuevo :  283  hospital A tiempo  0
# Llega paciente nuevo :  284  hospital B tiempo  0
# Llega paciente nuevo :  285  hospital B tiempo  0
# Llega paciente nuevo :  286  hospital A tiempo  0
# Llega paciente nuevo :  287  hospital B tiempo  0
# Llega paciente nuevo :  288  hospital A tiempo  0
# Llega paciente nuevo :  289  hospital A tiempo  0
# Llega paciente nuevo :  290  hospital B tiempo  0
# Llega paciente nuevo :  291  hospital B tiempo  0
# Llega paciente nuevo :  292  hospital A tiempo  0
# Llega paciente nuevo :  293  hospital A tiempo  0
# Llega paciente nuevo :  294  hospital A tiempo  0
# Llega paciente nuevo :  295  hospital A tiempo  0
# Llega paciente nuevo :  296  hospital A tiempo  0
# Llega paciente nuevo :  297  hospital A tiempo  0
# Llega paciente nuevo :  298  hospital B tiempo  0
# Llega paciente nuevo :  299  hospital B tiempo  0
# Llega paciente nuevo :  300  hospital B tiempo  0
# Llega paciente nuevo :  301  hospital B tiempo  0
# Llega paciente nuevo :  302  hospital B tiempo  0
# Llega paciente nuevo :  303  hospital A tiempo  0
# Llega paciente nuevo :  304  hospital A tiempo  0
# Llega paciente nuevo :  305  hospital B tiempo  0
# Llega paciente nuevo :  306  hospital B tiempo  0
# Llega paciente nuevo :  307  hospital B tiempo  0
# Llega paciente nuevo :  308  hospital A tiempo  0
# Llega paciente nuevo :  309  hospital A tiempo  0
# Llega paciente nuevo :  310  hospital B tiempo  0
# Llega paciente nuevo :  311  hospital B tiempo  0
# Llega paciente nuevo :  312  hospital B tiempo  0
# Llega paciente nuevo :  313  hospital A tiempo  0
# Llega paciente nuevo :  314  hospital B tiempo  0
# Llega paciente nuevo :  315  hospital A tiempo  0
# Llega paciente nuevo :  316  hospital A tiempo  0
# Llega paciente nuevo :  317  hospital B tiempo  0
# Llega paciente nuevo :  318  hospital B tiempo  0
# Llega paciente nuevo :  319  hospital A tiempo  0
# Llega paciente nuevo :  320  hospital B tiempo  0
# Llega paciente nuevo :  321  hospital A tiempo  0
# Llega paciente nuevo :  322  hospital A tiempo  0
# Llega paciente nuevo :  323  hospital B tiempo  0
# Llega paciente nuevo :  324  hospital B tiempo  0
# Llega paciente nuevo :  325  hospital A tiempo  0
# Llega paciente nuevo :  326  hospital A tiempo  0
# Llega paciente nuevo :  327  hospital B tiempo  0
# Llega paciente nuevo :  328  hospital A tiempo  0
# Llega paciente nuevo :  329  hospital B tiempo  0
# Llega paciente nuevo :  330  hospital B tiempo  0
# Llega paciente nuevo :  331  hospital B tiempo  0
# Llega paciente nuevo :  332  hospital A tiempo  0
# Llega paciente nuevo :  333  hospital A tiempo  0
# Llega paciente nuevo :  334  hospital A tiempo  0
# Llega paciente nuevo :  335  hospital B tiempo  0
# Llega paciente nuevo :  336  hospital A tiempo  0
# Llega paciente nuevo :  337  hospital A tiempo  0
# Llega paciente nuevo :  338  hospital B tiempo  0
# Llega paciente nuevo :  339  hospital A tiempo  0
# Llega paciente nuevo :  340  hospital A tiempo  0
# Llega paciente nuevo :  341  hospital B tiempo  0
# Llega paciente nuevo :  342  hospital A tiempo  0
# Llega paciente nuevo :  343  hospital A tiempo  0
# Llega paciente nuevo :  344  hospital A tiempo  0
# Llega paciente nuevo :  345  hospital A tiempo  0
# Llega paciente nuevo :  346  hospital A tiempo  0
# Llega paciente nuevo :  347  hospital B tiempo  0
# Llega paciente nuevo :  348  hospital B tiempo  0
# Llega paciente nuevo :  349  hospital A tiempo  0
# Llega paciente nuevo :  350  hospital B tiempo  0
# Llega paciente nuevo :  351  hospital A tiempo  0
# Llega paciente nuevo :  352  hospital B tiempo  0
# Llega paciente nuevo :  353  hospital A tiempo  0
# Llega paciente nuevo :  354  hospital A tiempo  0
# Llega paciente nuevo :  355  hospital B tiempo  0
# Llega paciente nuevo :  356  hospital B tiempo  0
# Llega paciente nuevo :  357  hospital A tiempo  0
# Llega paciente nuevo :  358  hospital A tiempo  0
# Llega paciente nuevo :  359  hospital B tiempo  0
# Llega paciente nuevo :  360  hospital B tiempo  0
# Llega paciente nuevo :  361  hospital B tiempo  0
# Llega paciente nuevo :  362  hospital A tiempo  0
# Llega paciente nuevo :  363  hospital A tiempo  0
# Llega paciente nuevo :  364  hospital B tiempo  0
# Llega paciente nuevo :  365  hospital A tiempo  0
# Llega paciente nuevo :  366  hospital B tiempo  0
# Llega paciente nuevo :  367  hospital B tiempo  0
# Llega paciente nuevo :  368  hospital A tiempo  0
# Llega paciente nuevo :  369  hospital B tiempo  0
# Llega paciente nuevo :  370  hospital B tiempo  0
# Llega paciente nuevo :  371  hospital A tiempo  0
# Llega paciente nuevo :  372  hospital A tiempo  0
# Llega paciente nuevo :  373  hospital A tiempo  0
# Llega paciente nuevo :  374  hospital B tiempo  0
# Llega paciente nuevo :  375  hospital B tiempo  0
# Llega paciente nuevo :  376  hospital A tiempo  0
# Llega paciente nuevo :  377  hospital B tiempo  0
# Llega paciente nuevo :  378  hospital B tiempo  0
# Llega paciente nuevo :  379  hospital B tiempo  0
# Llega paciente nuevo :  380  hospital B tiempo  0
# Llega paciente nuevo :  381  hospital B tiempo  0
# Llega paciente nuevo :  382  hospital A tiempo  0
# Llega paciente nuevo :  383  hospital A tiempo  0
# Llega paciente nuevo :  384  hospital A tiempo  0
# Llega paciente nuevo :  385  hospital B tiempo  0
# Llega paciente nuevo :  386  hospital B tiempo  0
# Llega paciente nuevo :  387  hospital A tiempo  0
# Llega paciente nuevo :  388  hospital B tiempo  0
# Llega paciente nuevo :  389  hospital B tiempo  0
# Llega paciente nuevo :  390  hospital A tiempo  0
# Llega paciente nuevo :  391  hospital A tiempo  0
# Llega paciente nuevo :  392  hospital B tiempo  0
# Llega paciente nuevo :  393  hospital A tiempo  0
# Llega paciente nuevo :  394  hospital B tiempo  0
# Llega paciente nuevo :  395  hospital A tiempo  0
# Llega paciente nuevo :  396  hospital A tiempo  0
# Llega paciente nuevo :  397  hospital A tiempo  0
# Llega paciente nuevo :  398  hospital B tiempo  0
# Llega paciente nuevo :  399  hospital A tiempo  0
# Llega paciente nuevo :  400  hospital A tiempo  0
# Llega paciente nuevo :  401  hospital A tiempo  0
# Llega paciente nuevo :  402  hospital B tiempo  0
# Llega paciente nuevo :  403  hospital B tiempo  0
# Llega paciente nuevo :  404  hospital A tiempo  0
# Llega paciente nuevo :  405  hospital A tiempo  0
# Llega paciente nuevo :  406  hospital B tiempo  0
# Llega paciente nuevo :  407  hospital B tiempo  0
# Llega paciente nuevo :  408  hospital B tiempo  0
# Llega paciente nuevo :  409  hospital B tiempo  0
# Llega paciente nuevo :  410  hospital B tiempo  0
# Llega paciente nuevo :  411  hospital A tiempo  0
# Llega paciente nuevo :  412  hospital B tiempo  0
# Llega paciente nuevo :  413  hospital B tiempo  0
# Llega paciente nuevo :  414  hospital B tiempo  0
# Llega paciente nuevo :  415  hospital B tiempo  0
# Llega paciente nuevo :  416  hospital A tiempo  0
# Llega paciente nuevo :  417  hospital B tiempo  0
# Llega paciente nuevo :  418  hospital B tiempo  0
# Llega paciente nuevo :  419  hospital B tiempo  0
# Llega paciente nuevo :  420  hospital A tiempo  0
# Llega paciente nuevo :  421  hospital A tiempo  0
# Llega paciente nuevo :  422  hospital A tiempo  0
# Llega paciente nuevo :  423  hospital A tiempo  0
# Llega paciente nuevo :  424  hospital B tiempo  0
# Llega paciente nuevo :  425  hospital A tiempo  0
# Llega paciente nuevo :  426  hospital A tiempo  0
# Llega paciente nuevo :  427  hospital B tiempo  0
# Llega paciente nuevo :  428  hospital B tiempo  0
# Llega paciente nuevo :  429  hospital B tiempo  0
# Llega paciente nuevo :  430  hospital A tiempo  0
# Llega paciente nuevo :  431  hospital A tiempo  0
# Llega paciente nuevo :  432  hospital B tiempo  0
# Llega paciente nuevo :  433  hospital B tiempo  0
# Llega paciente nuevo :  434  hospital B tiempo  0
# Llega paciente nuevo :  435  hospital A tiempo  0
# Llega paciente nuevo :  436  hospital B tiempo  0
# Llega paciente nuevo :  437  hospital B tiempo  0
# Llega paciente nuevo :  438  hospital A tiempo  0
# Llega paciente nuevo :  439  hospital A tiempo  0
# Llega paciente nuevo :  440  hospital A tiempo  0
# Llega paciente nuevo :  441  hospital B tiempo  0
# Llega paciente nuevo :  442  hospital A tiempo  0
# Llega paciente nuevo :  443  hospital B tiempo  0
# Llega paciente nuevo :  444  hospital A tiempo  0
# Llega paciente nuevo :  445  hospital A tiempo  0
# Llega paciente nuevo :  446  hospital B tiempo  0
# Llega paciente nuevo :  447  hospital A tiempo  0
# Llega paciente nuevo :  448  hospital A tiempo  0
# Llega paciente nuevo :  449  hospital A tiempo  0
# Llega paciente nuevo :  450  hospital A tiempo  0
# Llega paciente nuevo :  451  hospital A tiempo  0
# Llega paciente nuevo :  452  hospital B tiempo  0
# Llega paciente nuevo :  453  hospital A tiempo  0
# Llega paciente nuevo :  454  hospital A tiempo  0
# Llega paciente nuevo :  455  hospital A tiempo  0
# Llega paciente nuevo :  456  hospital B tiempo  0
# Llega paciente nuevo :  457  hospital B tiempo  0
# Llega paciente nuevo :  458  hospital B tiempo  0
# Llega paciente nuevo :  459  hospital A tiempo  0
# Llega paciente nuevo :  460  hospital A tiempo  0
# Llega paciente nuevo :  461  hospital A tiempo  0
# Llega paciente nuevo :  462  hospital A tiempo  0
# Llega paciente nuevo :  463  hospital A tiempo  0
# Llega paciente nuevo :  464  hospital A tiempo  0
# Llega paciente nuevo :  465  hospital A tiempo  0
# Llega paciente nuevo :  466  hospital A tiempo  0
# Llega paciente nuevo :  467  hospital A tiempo  0
# Llega paciente nuevo :  468  hospital A tiempo  0
# Llega paciente nuevo :  469  hospital A tiempo  0
# Llega paciente nuevo :  470  hospital A tiempo  0
# Llega paciente nuevo :  471  hospital B tiempo  0
# Llega paciente nuevo :  472  hospital A tiempo  0
# Llega paciente nuevo :  473  hospital B tiempo  0
# Llega paciente nuevo :  474  hospital A tiempo  0
# Llega paciente nuevo :  475  hospital A tiempo  0
# Llega paciente nuevo :  476  hospital A tiempo  0
# Llega paciente nuevo :  477  hospital A tiempo  0
# Llega paciente nuevo :  478  hospital B tiempo  0
# Llega paciente nuevo :  479  hospital B tiempo  0
# Llega paciente nuevo :  480  hospital A tiempo  0
# Llega paciente nuevo :  481  hospital A tiempo  0
# Llega paciente nuevo :  482  hospital B tiempo  0
# Llega paciente nuevo :  483  hospital B tiempo  0
# Llega paciente nuevo :  484  hospital A tiempo  0
# Llega paciente nuevo :  485  hospital B tiempo  0
# Llega paciente nuevo :  486  hospital A tiempo  0
# Llega paciente nuevo :  487  hospital B tiempo  0
# Llega paciente nuevo :  488  hospital B tiempo  0
# Llega paciente nuevo :  489  hospital A tiempo  0
# Llega paciente nuevo :  490  hospital A tiempo  0
# Llega paciente nuevo :  491  hospital A tiempo  0
# Llega paciente nuevo :  492  hospital A tiempo  0
# Llega paciente nuevo :  493  hospital A tiempo  0
# Llega paciente nuevo :  494  hospital B tiempo  0
# Llega paciente nuevo :  495  hospital A tiempo  0
# Llega paciente nuevo :  496  hospital A tiempo  0
# Llega paciente nuevo :  497  hospital B tiempo  0
# Llega paciente nuevo :  498  hospital A tiempo  0
# Llega paciente nuevo :  499  hospital A tiempo  0
# Llega paciente nuevo :  500  hospital B tiempo  0
# Llega paciente nuevo :  501  hospital B tiempo  0
# Llega paciente nuevo :  502  hospital A tiempo  0
# Llega paciente nuevo :  503  hospital B tiempo  0
# Llega paciente nuevo :  504  hospital B tiempo  0
# Llega paciente nuevo :  505  hospital B tiempo  0
# Llega paciente nuevo :  506  hospital A tiempo  0
# Llega paciente nuevo :  507  hospital B tiempo  0
# Llega paciente nuevo :  508  hospital A tiempo  0
# Llega paciente nuevo :  509  hospital B tiempo  0
# Llega paciente nuevo :  510  hospital B tiempo  0
# Llega paciente nuevo :  511  hospital B tiempo  0
# Llega paciente nuevo :  512  hospital B tiempo  0
# Llega paciente nuevo :  513  hospital A tiempo  0
# Llega paciente nuevo :  514  hospital A tiempo  0
# Llega paciente nuevo :  515  hospital A tiempo  0
# Llega paciente nuevo :  516  hospital A tiempo  0
# Llega paciente nuevo :  517  hospital A tiempo  0
# Llega paciente nuevo :  518  hospital A tiempo  0
# Llega paciente nuevo :  519  hospital A tiempo  0
# Llega paciente nuevo :  520  hospital B tiempo  0
# Llega paciente nuevo :  521  hospital B tiempo  0
# Llega paciente nuevo :  522  hospital A tiempo  0
# Llega paciente nuevo :  523  hospital A tiempo  0
# Llega paciente nuevo :  524  hospital B tiempo  0
# Llega paciente nuevo :  525  hospital A tiempo  0
# Llega paciente nuevo :  526  hospital A tiempo  0
# Llega paciente nuevo :  527  hospital A tiempo  0
# Llega paciente nuevo :  528  hospital A tiempo  0
# Llega paciente nuevo :  529  hospital A tiempo  0
# Llega paciente nuevo :  530  hospital B tiempo  0
# Llega paciente nuevo :  531  hospital B tiempo  0
# Llega paciente nuevo :  532  hospital B tiempo  0
# Llega paciente nuevo :  533  hospital B tiempo  0
# Llega paciente nuevo :  534  hospital B tiempo  0
# Llega paciente nuevo :  535  hospital B tiempo  0
# Llega paciente nuevo :  536  hospital A tiempo  0
# Llega paciente nuevo :  537  hospital B tiempo  0
# Llega paciente nuevo :  538  hospital A tiempo  0
# Llega paciente nuevo :  539  hospital B tiempo  0
# Llega paciente nuevo :  540  hospital A tiempo  0
# Llega paciente nuevo :  541  hospital A tiempo  0
# Llega paciente nuevo :  542  hospital A tiempo  0
# Llega paciente nuevo :  543  hospital A tiempo  0
# Llega paciente nuevo :  544  hospital B tiempo  0
# Llega paciente nuevo :  545  hospital A tiempo  0
# Llega paciente nuevo :  546  hospital A tiempo  0
# Llega paciente nuevo :  547  hospital B tiempo  0
# Llega paciente nuevo :  548  hospital A tiempo  0
# Llega paciente nuevo :  549  hospital B tiempo  0
# Llega paciente nuevo :  550  hospital B tiempo  0
# Llega paciente nuevo :  551  hospital A tiempo  0
# Llega paciente nuevo :  552  hospital B tiempo  0
# Llega paciente nuevo :  553  hospital B tiempo  0
# Llega paciente nuevo :  554  hospital B tiempo  0
# Llega paciente nuevo :  555  hospital A tiempo  0
# Llega paciente nuevo :  556  hospital B tiempo  0
# Llega paciente nuevo :  557  hospital B tiempo  0
# Llega paciente nuevo :  558  hospital B tiempo  0
# Llega paciente nuevo :  559  hospital A tiempo  0
# Llega paciente nuevo :  560  hospital A tiempo  0
# Llega paciente nuevo :  561  hospital B tiempo  0
# Llega paciente nuevo :  562  hospital B tiempo  0
# Llega paciente nuevo :  563  hospital A tiempo  0
# Llega paciente nuevo :  564  hospital A tiempo  0
# Llega paciente nuevo :  565  hospital B tiempo  0
# Llega paciente nuevo :  566  hospital B tiempo  0
# Llega paciente nuevo :  567  hospital B tiempo  0
# Llega paciente nuevo :  568  hospital B tiempo  0
# Llega paciente nuevo :  569  hospital A tiempo  0
# Llega paciente nuevo :  570  hospital B tiempo  0
# Llega paciente nuevo :  571  hospital B tiempo  0
# Llega paciente nuevo :  572  hospital A tiempo  0
# Llega paciente nuevo :  573  hospital B tiempo  0
# Llega paciente nuevo :  574  hospital B tiempo  0
# Llega paciente nuevo :  575  hospital A tiempo  0
# Llega paciente nuevo :  576  hospital A tiempo  0
# Llega paciente nuevo :  577  hospital A tiempo  0
# Llega paciente nuevo :  578  hospital A tiempo  0
# Llega paciente nuevo :  579  hospital A tiempo  0
# Llega paciente nuevo :  580  hospital B tiempo  0
# Llega paciente nuevo :  581  hospital A tiempo  0
# Llega paciente nuevo :  582  hospital B tiempo  0
# Llega paciente nuevo :  583  hospital A tiempo  0
# Llega paciente nuevo :  584  hospital B tiempo  0
# Llega paciente nuevo :  585  hospital B tiempo  0
# Llega paciente nuevo :  586  hospital B tiempo  0
# Llega paciente nuevo :  587  hospital A tiempo  0
# Llega paciente nuevo :  588  hospital A tiempo  0
# Llega paciente nuevo :  589  hospital A tiempo  0
# Llega paciente nuevo :  590  hospital B tiempo  0
# Llega paciente nuevo :  591  hospital B tiempo  0
# Llega paciente nuevo :  592  hospital A tiempo  0
# Llega paciente nuevo :  593  hospital A tiempo  0
# Llega paciente nuevo :  594  hospital B tiempo  0
# Llega paciente nuevo :  595  hospital B tiempo  0
# Llega paciente nuevo :  596  hospital A tiempo  0
# Llega paciente nuevo :  597  hospital A tiempo  0
# Llega paciente nuevo :  598  hospital A tiempo  0
# Llega paciente nuevo :  599  hospital A tiempo  0
# Llega paciente nuevo :  600  hospital B tiempo  0
# Llega paciente nuevo :  601  hospital B tiempo  0
# Llega paciente nuevo :  602  hospital A tiempo  0
# Llega paciente nuevo :  603  hospital B tiempo  0
# Llega paciente nuevo :  604  hospital B tiempo  0
# Llega paciente nuevo :  605  hospital B tiempo  0
# Llega paciente nuevo :  606  hospital B tiempo  0
# Llega paciente nuevo :  607  hospital A tiempo  0
# Llega paciente nuevo :  608  hospital A tiempo  0
# Llega paciente nuevo :  609  hospital A tiempo  0
# Llega paciente nuevo :  610  hospital A tiempo  0
# Llega paciente nuevo :  611  hospital B tiempo  0
# Llega paciente nuevo :  612  hospital A tiempo  0
# Llega paciente nuevo :  613  hospital B tiempo  0
# Llega paciente nuevo :  614  hospital B tiempo  0
# Llega paciente nuevo :  615  hospital A tiempo  0
# Llega paciente nuevo :  616  hospital A tiempo  0
# Llega paciente nuevo :  617  hospital A tiempo  0
# Llega paciente nuevo :  618  hospital B tiempo  0
# Llega paciente nuevo :  619  hospital B tiempo  0
# Llega paciente nuevo :  620  hospital A tiempo  0
# Llega paciente nuevo :  621  hospital A tiempo  0
# Llega paciente nuevo :  622  hospital B tiempo  0
# Llega paciente nuevo :  623  hospital B tiempo  0
# Llega paciente nuevo :  624  hospital B tiempo  0
# Llega paciente nuevo :  625  hospital B tiempo  0
# Llega paciente nuevo :  626  hospital B tiempo  0
# Llega paciente nuevo :  627  hospital A tiempo  0
# Llega paciente nuevo :  628  hospital B tiempo  0
# Llega paciente nuevo :  629  hospital B tiempo  0
# Llega paciente nuevo :  630  hospital A tiempo  0
# Llega paciente nuevo :  631  hospital B tiempo  0
# Llega paciente nuevo :  632  hospital B tiempo  0
# Llega paciente nuevo :  633  hospital B tiempo  0
# Llega paciente nuevo :  634  hospital A tiempo  0
# Llega paciente nuevo :  635  hospital B tiempo  0
# Llega paciente nuevo :  636  hospital B tiempo  0
# Llega paciente nuevo :  637  hospital B tiempo  0
# Llega paciente nuevo :  638  hospital A tiempo  0
# Llega paciente nuevo :  639  hospital A tiempo  0
# Llega paciente nuevo :  640  hospital B tiempo  0
# Llega paciente nuevo :  641  hospital B tiempo  0
# Llega paciente nuevo :  642  hospital B tiempo  0
# Llega paciente nuevo :  643  hospital B tiempo  0
# Llega paciente nuevo :  644  hospital B tiempo  0
# Llega paciente nuevo :  645  hospital B tiempo  0
# Llega paciente nuevo :  646  hospital A tiempo  0
# Llega paciente nuevo :  647  hospital A tiempo  0
# Llega paciente nuevo :  648  hospital B tiempo  0
# Llega paciente nuevo :  649  hospital B tiempo  0
# Llega paciente nuevo :  650  hospital A tiempo  0
# Llega paciente nuevo :  651  hospital B tiempo  0
# Llega paciente nuevo :  652  hospital B tiempo  0
# Llega paciente nuevo :  653  hospital A tiempo  0
# Llega paciente nuevo :  654  hospital A tiempo  0
# Llega paciente nuevo :  655  hospital B tiempo  0
# Llega paciente nuevo :  656  hospital A tiempo  0
# Llega paciente nuevo :  657  hospital A tiempo  0
# Llega paciente nuevo :  658  hospital A tiempo  0
# Llega paciente nuevo :  659  hospital B tiempo  0
# Llega paciente nuevo :  660  hospital B tiempo  0
# Llega paciente nuevo :  661  hospital A tiempo  0
# Llega paciente nuevo :  662  hospital A tiempo  0
# Llega paciente nuevo :  663  hospital A tiempo  0
# Llega paciente nuevo :  664  hospital B tiempo  0
# Llega paciente nuevo :  665  hospital A tiempo  0
# Llega paciente nuevo :  666  hospital A tiempo  0
# Llega paciente nuevo :  667  hospital A tiempo  0
# Llega paciente nuevo :  668  hospital A tiempo  0
# Llega paciente nuevo :  669  hospital A tiempo  0
# Llega paciente nuevo :  670  hospital B tiempo  0
# Llega paciente nuevo :  671  hospital A tiempo  0
# Llega paciente nuevo :  672  hospital A tiempo  0
# Llega paciente nuevo :  673  hospital B tiempo  0
# Llega paciente nuevo :  674  hospital B tiempo  0
# Llega paciente nuevo :  675  hospital A tiempo  0
# Llega paciente nuevo :  676  hospital A tiempo  0
# Llega paciente nuevo :  677  hospital A tiempo  0
# Llega paciente nuevo :  678  hospital A tiempo  0
# Llega paciente nuevo :  679  hospital B tiempo  0
# Llega paciente nuevo :  680  hospital A tiempo  0
# Llega paciente nuevo :  681  hospital B tiempo  0
# Llega paciente nuevo :  682  hospital B tiempo  0
# Llega paciente nuevo :  683  hospital B tiempo  0
# Llega paciente nuevo :  684  hospital A tiempo  0
# Llega paciente nuevo :  685  hospital B tiempo  0
# Llega paciente nuevo :  686  hospital A tiempo  0
# Llega paciente nuevo :  687  hospital B tiempo  0
# Llega paciente nuevo :  688  hospital A tiempo  0
# Llega paciente nuevo :  689  hospital A tiempo  0
# Llega paciente nuevo :  690  hospital B tiempo  0
# Llega paciente nuevo :  691  hospital A tiempo  0
# Llega paciente nuevo :  692  hospital A tiempo  0
# Llega paciente nuevo :  693  hospital A tiempo  0
# Llega paciente nuevo :  694  hospital A tiempo  0
# Llega paciente nuevo :  695  hospital B tiempo  0
# Llega paciente nuevo :  696  hospital B tiempo  0
# Llega paciente nuevo :  697  hospital A tiempo  0
# Llega paciente nuevo :  698  hospital A tiempo  0
# Llega paciente nuevo :  699  hospital A tiempo  0
# Llega paciente nuevo :  700  hospital A tiempo  0
# Llega paciente nuevo :  701  hospital B tiempo  0
# Llega paciente nuevo :  702  hospital A tiempo  0
# Llega paciente nuevo :  703  hospital A tiempo  0
# Llega paciente nuevo :  704  hospital A tiempo  0
# Llega paciente nuevo :  705  hospital A tiempo  0
# Llega paciente nuevo :  706  hospital B tiempo  0
# Llega paciente nuevo :  707  hospital B tiempo  0
# Llega paciente nuevo :  708  hospital B tiempo  0
# Llega paciente nuevo :  709  hospital A tiempo  0
# Llega paciente nuevo :  710  hospital A tiempo  0
# Llega paciente nuevo :  711  hospital B tiempo  0
# Llega paciente nuevo :  712  hospital B tiempo  0
# Llega paciente nuevo :  713  hospital A tiempo  0
# Llega paciente nuevo :  714  hospital A tiempo  0
# Llega paciente nuevo :  715  hospital A tiempo  0
# Llega paciente nuevo :  716  hospital A tiempo  0
# Llega paciente nuevo :  717  hospital A tiempo  0
# Llega paciente nuevo :  718  hospital B tiempo  0
# Llega paciente nuevo :  719  hospital A tiempo  0
# Llega paciente nuevo :  720  hospital B tiempo  0
# Llega paciente nuevo :  721  hospital A tiempo  0
# Llega paciente nuevo :  722  hospital A tiempo  0
# Llega paciente nuevo :  723  hospital B tiempo  0
# Llega paciente nuevo :  724  hospital B tiempo  0
# Llega paciente nuevo :  725  hospital A tiempo  0
# Llega paciente nuevo :  726  hospital B tiempo  0
# Llega paciente nuevo :  727  hospital A tiempo  0
# Llega paciente nuevo :  728  hospital A tiempo  0
# Llega paciente nuevo :  729  hospital B tiempo  0
# Llega paciente nuevo :  730  hospital A tiempo  0
# Llega paciente nuevo :  731  hospital B tiempo  0
# Llega paciente nuevo :  732  hospital A tiempo  0
# Llega paciente nuevo :  733  hospital A tiempo  0
# Llega paciente nuevo :  734  hospital B tiempo  0
# Llega paciente nuevo :  735  hospital B tiempo  0
# Llega paciente nuevo :  736  hospital B tiempo  0
# Llega paciente nuevo :  737  hospital A tiempo  0
# Llega paciente nuevo :  738  hospital B tiempo  0
# Llega paciente nuevo :  739  hospital A tiempo  0
# Llega paciente nuevo :  740  hospital A tiempo  0
# Llega paciente nuevo :  741  hospital A tiempo  0
# Llega paciente nuevo :  742  hospital A tiempo  0
# Llega paciente nuevo :  743  hospital B tiempo  0
# Llega paciente nuevo :  744  hospital B tiempo  0
# Llega paciente nuevo :  745  hospital B tiempo  0
# Llega paciente nuevo :  746  hospital B tiempo  0
# Llega paciente nuevo :  747  hospital B tiempo  0
# Llega paciente nuevo :  748  hospital A tiempo  0
# Llega paciente nuevo :  749  hospital A tiempo  0
# Llega paciente nuevo :  750  hospital A tiempo  0
# Llega paciente nuevo :  751  hospital B tiempo  0
# Llega paciente nuevo :  752  hospital B tiempo  0
# Llega paciente nuevo :  753  hospital A tiempo  0
# Llega paciente nuevo :  754  hospital A tiempo  0
# Llega paciente nuevo :  755  hospital B tiempo  0
# Llega paciente nuevo :  756  hospital B tiempo  0
# Llega paciente nuevo :  757  hospital A tiempo  0
# Llega paciente nuevo :  758  hospital B tiempo  0
# Llega paciente nuevo :  759  hospital A tiempo  0
# Llega paciente nuevo :  760  hospital A tiempo  0
# Llega paciente nuevo :  761  hospital B tiempo  0
# Llega paciente nuevo :  762  hospital B tiempo  0
# Llega paciente nuevo :  763  hospital A tiempo  0
# Llega paciente nuevo :  764  hospital B tiempo  0
# Llega paciente nuevo :  765  hospital A tiempo  0
# Llega paciente nuevo :  766  hospital B tiempo  0
# Llega paciente nuevo :  767  hospital A tiempo  0
# Llega paciente nuevo :  768  hospital A tiempo  0
# Llega paciente nuevo :  769  hospital A tiempo  0
# Llega paciente nuevo :  770  hospital B tiempo  0
# Llega paciente nuevo :  771  hospital B tiempo  0
# Llega paciente nuevo :  772  hospital A tiempo  0
# Llega paciente nuevo :  773  hospital A tiempo  0
# Llega paciente nuevo :  774  hospital A tiempo  0
# Llega paciente nuevo :  775  hospital B tiempo  0
# Llega paciente nuevo :  776  hospital A tiempo  0
# Llega paciente nuevo :  777  hospital B tiempo  0
# Llega paciente nuevo :  778  hospital A tiempo  0
# Llega paciente nuevo :  779  hospital A tiempo  0
# Llega paciente nuevo :  780  hospital B tiempo  0
# Llega paciente nuevo :  781  hospital A tiempo  0
# Llega paciente nuevo :  782  hospital B tiempo  0
# Llega paciente nuevo :  783  hospital B tiempo  0
# Llega paciente nuevo :  784  hospital A tiempo  0
# Llega paciente nuevo :  785  hospital B tiempo  0
# Llega paciente nuevo :  786  hospital B tiempo  0
# Llega paciente nuevo :  787  hospital B tiempo  0
# Llega paciente nuevo :  788  hospital A tiempo  0
# Llega paciente nuevo :  789  hospital B tiempo  0
# Llega paciente nuevo :  790  hospital B tiempo  0
# Llega paciente nuevo :  791  hospital A tiempo  0
# Llega paciente nuevo :  792  hospital A tiempo  0
# Llega paciente nuevo :  793  hospital B tiempo  0
# Llega paciente nuevo :  794  hospital B tiempo  0
# Llega paciente nuevo :  795  hospital A tiempo  0
# Llega paciente nuevo :  796  hospital B tiempo  0
# Llega paciente nuevo :  797  hospital B tiempo  0
# Llega paciente nuevo :  798  hospital B tiempo  0
# Llega paciente nuevo :  799  hospital A tiempo  0
# Llega paciente nuevo :  800  hospital B tiempo  0
# Llega paciente nuevo :  801  hospital B tiempo  0
# Llega paciente nuevo :  802  hospital A tiempo  0
# Llega paciente nuevo :  803  hospital A tiempo  0
# Llega paciente nuevo :  804  hospital A tiempo  0
# Llega paciente nuevo :  805  hospital A tiempo  0
# Llega paciente nuevo :  806  hospital B tiempo  0
# Llega paciente nuevo :  807  hospital A tiempo  0
# Llega paciente nuevo :  808  hospital A tiempo  0
# Llega paciente nuevo :  809  hospital A tiempo  0
# Llega paciente nuevo :  810  hospital A tiempo  0
# Llega paciente nuevo :  811  hospital A tiempo  0
# Llega paciente nuevo :  812  hospital B tiempo  0
# Llega paciente nuevo :  813  hospital B tiempo  0
# Llega paciente nuevo :  814  hospital A tiempo  0
# Llega paciente nuevo :  815  hospital B tiempo  0
# Llega paciente nuevo :  816  hospital A tiempo  0
# Llega paciente nuevo :  817  hospital A tiempo  0
# Llega paciente nuevo :  818  hospital B tiempo  0
# Llega paciente nuevo :  819  hospital A tiempo  0
# Llega paciente nuevo :  820  hospital B tiempo  0
# Llega paciente nuevo :  821  hospital B tiempo  0
# Llega paciente nuevo :  822  hospital B tiempo  0
# Llega paciente nuevo :  823  hospital A tiempo  0
# Llega paciente nuevo :  824  hospital B tiempo  0
# Llega paciente nuevo :  825  hospital B tiempo  0
# Llega paciente nuevo :  826  hospital A tiempo  0
# Llega paciente nuevo :  827  hospital A tiempo  0
# Llega paciente nuevo :  828  hospital B tiempo  0
# Llega paciente nuevo :  829  hospital A tiempo  0
# Llega paciente nuevo :  830  hospital A tiempo  0
# Llega paciente nuevo :  831  hospital A tiempo  0
# Llega paciente nuevo :  832  hospital A tiempo  0
# Llega paciente nuevo :  833  hospital B tiempo  0
# Llega paciente nuevo :  834  hospital B tiempo  0
# Llega paciente nuevo :  835  hospital A tiempo  0
# Llega paciente nuevo :  836  hospital A tiempo  0
# Llega paciente nuevo :  837  hospital A tiempo  0
# Llega paciente nuevo :  838  hospital A tiempo  0
# Llega paciente nuevo :  839  hospital B tiempo  0
# Llega paciente nuevo :  840  hospital A tiempo  0
# Llega paciente nuevo :  841  hospital B tiempo  0
# Llega paciente nuevo :  842  hospital A tiempo  0
# Llega paciente nuevo :  843  hospital B tiempo  0
# Llega paciente nuevo :  844  hospital A tiempo  0
# Llega paciente nuevo :  845  hospital B tiempo  0
# Llega paciente nuevo :  846  hospital A tiempo  0
# Llega paciente nuevo :  847  hospital B tiempo  0
# Llega paciente nuevo :  848  hospital A tiempo  0
# Llega paciente nuevo :  849  hospital A tiempo  0
# Llega paciente nuevo :  850  hospital A tiempo  0
# Llega paciente nuevo :  851  hospital B tiempo  0
# Llega paciente nuevo :  852  hospital B tiempo  0
# Llega paciente nuevo :  853  hospital A tiempo  0
# Llega paciente nuevo :  854  hospital A tiempo  0
# Llega paciente nuevo :  855  hospital B tiempo  0
# Llega paciente nuevo :  856  hospital A tiempo  0
# Llega paciente nuevo :  857  hospital A tiempo  0
# Llega paciente nuevo :  858  hospital B tiempo  0
# Llega paciente nuevo :  859  hospital A tiempo  0
# Llega paciente nuevo :  860  hospital A tiempo  0
# Llega paciente nuevo :  861  hospital B tiempo  0
# Llega paciente nuevo :  862  hospital B tiempo  0
# Llega paciente nuevo :  863  hospital A tiempo  0
# Llega paciente nuevo :  864  hospital B tiempo  0
# Llega paciente nuevo :  865  hospital B tiempo  0
# Llega paciente nuevo :  866  hospital A tiempo  0
# Llega paciente nuevo :  867  hospital A tiempo  0
# Llega paciente nuevo :  868  hospital A tiempo  0
# Llega paciente nuevo :  869  hospital B tiempo  0
# Llega paciente nuevo :  870  hospital A tiempo  0
# Llega paciente nuevo :  871  hospital B tiempo  0
# Llega paciente nuevo :  872  hospital B tiempo  0
# Llega paciente nuevo :  873  hospital B tiempo  0
# Llega paciente nuevo :  874  hospital A tiempo  0
# Llega paciente nuevo :  875  hospital A tiempo  0
# Llega paciente nuevo :  876  hospital A tiempo  0
# Llega paciente nuevo :  877  hospital B tiempo  0
# Llega paciente nuevo :  878  hospital B tiempo  0
# Llega paciente nuevo :  879  hospital A tiempo  0
# Llega paciente nuevo :  880  hospital B tiempo  0
# Llega paciente nuevo :  881  hospital B tiempo  0
# Llega paciente nuevo :  882  hospital B tiempo  0
# Llega paciente nuevo :  883  hospital B tiempo  0
# Llega paciente nuevo :  884  hospital A tiempo  0
# Llega paciente nuevo :  885  hospital A tiempo  0
# Llega paciente nuevo :  886  hospital A tiempo  0
# Llega paciente nuevo :  887  hospital A tiempo  0
# Llega paciente nuevo :  888  hospital A tiempo  0
# Llega paciente nuevo :  889  hospital B tiempo  0
# Llega paciente nuevo :  890  hospital B tiempo  0
# Llega paciente nuevo :  891  hospital A tiempo  0
# Llega paciente nuevo :  892  hospital B tiempo  0
# Llega paciente nuevo :  893  hospital A tiempo  0
# Llega paciente nuevo :  894  hospital A tiempo  0
# Llega paciente nuevo :  895  hospital A tiempo  0
# Llega paciente nuevo :  896  hospital B tiempo  0
# Llega paciente nuevo :  897  hospital A tiempo  0
# Llega paciente nuevo :  898  hospital B tiempo  0
# Llega paciente nuevo :  899  hospital A tiempo  0
# Llega paciente nuevo :  900  hospital A tiempo  0
# Llega paciente nuevo :  901  hospital B tiempo  0
# Llega paciente nuevo :  902  hospital B tiempo  0
# Llega paciente nuevo :  903  hospital A tiempo  0
# Llega paciente nuevo :  904  hospital A tiempo  0
# Llega paciente nuevo :  905  hospital A tiempo  0
# Llega paciente nuevo :  906  hospital B tiempo  0
# Llega paciente nuevo :  907  hospital B tiempo  0
# Llega paciente nuevo :  908  hospital A tiempo  0
# Llega paciente nuevo :  909  hospital A tiempo  0
# Llega paciente nuevo :  910  hospital B tiempo  0
# Llega paciente nuevo :  911  hospital B tiempo  0
# Llega paciente nuevo :  912  hospital A tiempo  0
# Llega paciente nuevo :  913  hospital B tiempo  0
# Llega paciente nuevo :  914  hospital A tiempo  0
# Llega paciente nuevo :  915  hospital B tiempo  0
# Llega paciente nuevo :  916  hospital A tiempo  0
# Llega paciente nuevo :  917  hospital A tiempo  0
# Llega paciente nuevo :  918  hospital B tiempo  0
# Llega paciente nuevo :  919  hospital B tiempo  0
# Llega paciente nuevo :  920  hospital B tiempo  0
# Llega paciente nuevo :  921  hospital A tiempo  0
# Llega paciente nuevo :  922  hospital B tiempo  0
# Llega paciente nuevo :  923  hospital A tiempo  0
# Llega paciente nuevo :  924  hospital B tiempo  0
# Llega paciente nuevo :  925  hospital A tiempo  0
# Llega paciente nuevo :  926  hospital B tiempo  0
# Llega paciente nuevo :  927  hospital A tiempo  0
# Llega paciente nuevo :  928  hospital A tiempo  0
# Llega paciente nuevo :  929  hospital A tiempo  0
# Llega paciente nuevo :  930  hospital B tiempo  0
# Llega paciente nuevo :  931  hospital A tiempo  0
# Llega paciente nuevo :  932  hospital A tiempo  0
# Llega paciente nuevo :  933  hospital A tiempo  0
# Llega paciente nuevo :  934  hospital B tiempo  0
# Llega paciente nuevo :  935  hospital B tiempo  0
# Llega paciente nuevo :  936  hospital B tiempo  0
# Llega paciente nuevo :  937  hospital A tiempo  0
# Llega paciente nuevo :  938  hospital B tiempo  0
# Llega paciente nuevo :  939  hospital B tiempo  0
# Llega paciente nuevo :  940  hospital A tiempo  0
# Llega paciente nuevo :  941  hospital B tiempo  0
# Llega paciente nuevo :  942  hospital A tiempo  0
# Llega paciente nuevo :  943  hospital B tiempo  0
# Llega paciente nuevo :  944  hospital B tiempo  0
# Llega paciente nuevo :  945  hospital B tiempo  0
# Llega paciente nuevo :  946  hospital B tiempo  0
# Llega paciente nuevo :  947  hospital A tiempo  0
# Llega paciente nuevo :  948  hospital B tiempo  0
# Llega paciente nuevo :  949  hospital A tiempo  0
# Llega paciente nuevo :  950  hospital B tiempo  0
# Llega paciente nuevo :  951  hospital B tiempo  0
# Llega paciente nuevo :  952  hospital A tiempo  0
# Llega paciente nuevo :  953  hospital A tiempo  0
# Llega paciente nuevo :  954  hospital B tiempo  0
# Llega paciente nuevo :  955  hospital A tiempo  0
# Llega paciente nuevo :  956  hospital A tiempo  0
# Llega paciente nuevo :  957  hospital A tiempo  0
# Llega paciente nuevo :  958  hospital B tiempo  0
# Llega paciente nuevo :  959  hospital A tiempo  0
# Llega paciente nuevo :  960  hospital A tiempo  0
# ...
# El paciente  7280  en el hospital  A  espero  2  dias y fallece no hay camas
# El paciente  7285  en el hospital  B  espero  2  dias y fallece no hay camas
# El paciente  7288  en el hospital  A  espero  2  dias y fallece no hay camas
# El paciente  7290  en el hospital  B  espero  2  dias y fallece no hay camas
# El paciente  7291  en el hospital  A  espero  2  dias y fallece no hay camas
# El paciente  7292  en el hospital  A  espero  2  dias y fallece no hay camas
# El paciente  7296  en el hospital  B  espero  2  dias y fallece no hay camas
# El paciente  7300  en el hospital  A  espero  2  dias y fallece no hay camas
# El paciente  7305  en el hospital  B  espero  2  dias y fallece no hay camas
# El paciente  7306  en el hospital  A  espero  2  dias y fallece no hay camas
# El paciente  7309  en el hospital  A  espero  2  dias y fallece no hay camas
# El paciente  7310  en el hospital  A  espero  2  dias y fallece no hay camas
# El paciente  7312  en el hospital  B  espero  2  dias y fallece no hay camas
# El paciente  7313  en el hospital  B  espero  2  dias y fallece no hay camas
# El paciente  7315  en el hospital  B  espero  2  dias y fallece no hay camas
# El paciente  7316  en el hospital  A  espero  2  dias y fallece no hay camas
# El paciente  7319  en el hospital  B  espero  2  dias y fallece no hay camas
# El paciente  7320  en el hospital  A  espero  2  dias y fallece no hay camas
# El paciente  7323  en el hospital  A  espero  2  dias y fallece no hay camas
# El paciente  7327  en el hospital  A  espero  2  dias y fallece no hay camas
# El paciente  7328  en el hospital  A  espero  2  dias y fallece no hay camas
# El paciente  7331  en el hospital  A  espero  2  dias y fallece no hay camas
# El paciente  7334  en el hospital  B  espero  2  dias y fallece no hay camas
# El paciente  7335  en el hospital  A  espero  2  dias y fallece no hay camas
# El paciente  7337  en el hospital  A  espero  2  dias y fallece no hay camas
# El paciente  7338  en el hospital  A  espero  2  dias y fallece no hay camas
# El paciente  7340  en el hospital  B  espero  2  dias y fallece no hay camas
# El paciente  7344  en el hospital  A  espero  2  dias y fallece no hay camas
# El paciente  7347  en el hospital  B  espero  2  dias y fallece no hay camas
# El paciente  7350  en el hospital  A  espero  2  dias y fallece no hay camas
# El paciente  7352  en el hospital  B  espero  2  dias y fallece no hay camas
# El paciente  7353  en el hospital  A  espero  2  dias y fallece no hay camas
# El paciente  7355  en el hospital  B  espero  2  dias y fallece no hay camas
# El paciente  7362  en el hospital  A  espero  2  dias y fallece no hay camas
# El paciente  7364  en el hospital  B  espero  2  dias y fallece no hay camas
# El paciente  7365  en el hospital  A  espero  2  dias y fallece no hay camas
# El paciente  7373  en el hospital  A  espero  2  dias y fallece no hay camas
# El paciente  7380  en el hospital  A  espero  2  dias y fallece no hay camas
# El paciente  7385  en el hospital  A  espero  2  dias y fallece no hay camas
# El paciente  7386  en el hospital  B  espero  2  dias y fallece no hay camas
# El paciente  7388  en el hospital  B  espero  2  dias y fallece no hay camas
# El paciente  7391  en el hospital  A  espero  2  dias y fallece no hay camas
# El paciente  7394  en el hospital  A  espero  2  dias y fallece no hay camas
# El paciente  7395  en el hospital  B  espero  2  dias y fallece no hay camas
# El paciente  7403  en el hospital  A  espero  2  dias y fallece no hay camas
# El paciente  344  en el hospital  A  espero  19  dias y fallece no hay camas
# El paciente  7418  en el hospital  B  espero  1  dias y fallece no hay camas
# El paciente  7419  en el hospital  B  espero  1  dias y fallece no hay camas
# El paciente  7421  en el hospital  B  espero  1  dias y fallece no hay camas
# El paciente  7425  en el hospital  B  espero  1  dias y fallece no hay camas
# El paciente  7426  en el hospital  B  espero  1  dias y fallece no hay camas
# El paciente  7434  en el hospital  A  espero  1  dias y fallece no hay camas
# El paciente  7435  en el hospital  A  espero  1  dias y fallece no hay camas
# El paciente  7436  en el hospital  B  espero  1  dias y fallece no hay camas
# El paciente  7437  en el hospital  A  espero  1  dias y fallece no hay camas
# El paciente  7438  en el hospital  A  espero  1  dias y fallece no hay camas
# El paciente  7446  en el hospital  B  espero  1  dias y fallece no hay camas
# El paciente  7449  en el hospital  A  espero  1  dias y fallece no hay camas
# El paciente  7453  en el hospital  A  espero  1  dias y fallece no hay camas
# El paciente  7456  en el hospital  A  espero  1  dias y fallece no hay camas
# El paciente  7457  en el hospital  A  espero  1  dias y fallece no hay camas
# El paciente  7465  en el hospital  A  espero  1  dias y fallece no hay camas
# El paciente  7470  en el hospital  A  espero  1  dias y fallece no hay camas
# El paciente  7481  en el hospital  B  espero  1  dias y fallece no hay camas
# El paciente  7492  en el hospital  B  espero  1  dias y fallece no hay camas
# El paciente  7494  en el hospital  A  espero  1  dias y fallece no hay camas
# El paciente  7498  en el hospital  B  espero  1  dias y fallece no hay camas
# El paciente  7505  en el hospital  A  espero  1  dias y fallece no hay camas
# El paciente  7506  en el hospital  B  espero  1  dias y fallece no hay camas
# El paciente  7510  en el hospital  A  espero  1  dias y fallece no hay camas
# El paciente  7511  en el hospital  A  espero  1  dias y fallece no hay camas
# El paciente  7514  en el hospital  B  espero  1  dias y fallece no hay camas
# El paciente  7515  en el hospital  A  espero  1  dias y fallece no hay camas
# El paciente  7518  en el hospital  B  espero  1  dias y fallece no hay camas
# El paciente  7519  en el hospital  B  espero  1  dias y fallece no hay camas
# El paciente  7523  en el hospital  A  espero  1  dias y fallece no hay camas
# El paciente  7524  en el hospital  B  espero  1  dias y fallece no hay camas
# El paciente  7525  en el hospital  A  espero  1  dias y fallece no hay camas
# El paciente  7526  en el hospital  B  espero  1  dias y fallece no hay camas
# El paciente  7527  en el hospital  A  espero  1  dias y fallece no hay camas
# El paciente  7528  en el hospital  A  espero  1  dias y fallece no hay camas
# El paciente  7530  en el hospital  A  espero  1  dias y fallece no hay camas
# El paciente  7533  en el hospital  A  espero  1  dias y fallece no hay camas
# El paciente  7537  en el hospital  B  espero  1  dias y fallece no hay camas
# El paciente  7538  en el hospital  A  espero  1  dias y fallece no hay camas
# El paciente  7539  en el hospital  A  espero  1  dias y fallece no hay camas
# El paciente  7544  en el hospital  B  espero  1  dias y fallece no hay camas
# El paciente  7547  en el hospital  A  espero  1  dias y fallece no hay camas
# El paciente  7550  en el hospital  B  espero  1  dias y fallece no hay camas
# El paciente  7552  en el hospital  B  espero  1  dias y fallece no hay camas
# El paciente  7553  en el hospital  A  espero  1  dias y fallece no hay camas
# El paciente  7558  en el hospital  A  espero  1  dias y fallece no hay camas
# El paciente  7564  en el hospital  B  espero  1  dias y fallece no hay camas
# El paciente  7566  en el hospital  A  espero  1  dias y fallece no hay camas
# El paciente  7570  en el hospital  B  espero  1  dias y fallece no hay camas
# El paciente  7571  en el hospital  A  espero  1  dias y fallece no hay camas
# El paciente  7580  en el hospital  A  espero  1  dias y fallece no hay camas
# El paciente  7581  en el hospital  B  espero  1  dias y fallece no hay camas
# El paciente  7584  en el hospital  A  espero  1  dias y fallece no hay camas
# El paciente  7592  en el hospital  A  espero  1  dias y fallece no hay camas
# El paciente  7594  en el hospital  A  espero  1  dias y fallece no hay camas
# El paciente  7595  en el hospital  A  espero  1  dias y fallece no hay camas
# El paciente  7596  en el hospital  A  espero  1  dias y fallece no hay camas
# El paciente  7599  en el hospital  B  espero  1  dias y fallece no hay camas
# El paciente  7601  en el hospital  A  espero  1  dias y fallece no hay camas
# El paciente  7612  en el hospital  A  espero  1  dias y fallece no hay camas
# El paciente  7614  en el hospital  B  espero  1  dias y fallece no hay camas
# El paciente  7615  en el hospital  B  espero  1  dias y fallece no hay camas
# El paciente  7617  en el hospital  A  espero  1  dias y fallece no hay camas
# El paciente  7620  en el hospital  B  espero  1  dias y fallece no hay camas
# El paciente  7621  en el hospital  B  espero  1  dias y fallece no hay camas
# El paciente  7624  en el hospital  A  espero  1  dias y fallece no hay camas
# El paciente  7625  en el hospital  A  espero  1  dias y fallece no hay camas
# El paciente  7626  en el hospital  A  espero  1  dias y fallece no hay camas
# El paciente  7629  en el hospital  B  espero  1  dias y fallece no hay camas
# El paciente  7630  en el hospital  B  espero  1  dias y fallece no hay camas
# El paciente  7634  en el hospital  A  espero  1  dias y fallece no hay camas
# El paciente  7635  en el hospital  B  espero  1  dias y fallece no hay camas
# El paciente  7636  en el hospital  B  espero  1  dias y fallece no hay camas
# El paciente  7639  en el hospital  B  espero  1  dias y fallece no hay camas
# El paciente  7641  en el hospital  B  espero  1  dias y fallece no hay camas
# El paciente  7643  en el hospital  A  espero  1  dias y fallece no hay camas
# El paciente  7645  en el hospital  A  espero  1  dias y fallece no hay camas
# El paciente  7649  en el hospital  B  espero  1  dias y fallece no hay camas
# El paciente  7650  en el hospital  B  espero  1  dias y fallece no hay camas
# El paciente  7653  en el hospital  A  espero  1  dias y fallece no hay camas
# El paciente  7655  en el hospital  B  espero  1  dias y fallece no hay camas
# El paciente  7660  en el hospital  B  espero  1  dias y fallece no hay camas
# El paciente  7662  en el hospital  A  espero  1  dias y fallece no hay camas
# El paciente  7669  en el hospital  A  espero  1  dias y fallece no hay camas
# El paciente  7671  en el hospital  A  espero  1  dias y fallece no hay camas
# El paciente  7682  en el hospital  B  espero  1  dias y fallece no hay camas
# El paciente  7684  en el hospital  A  espero  1  dias y fallece no hay camas
# El paciente  7688  en el hospital  B  espero  1  dias y fallece no hay camas
# El paciente  7689  en el hospital  B  espero  1  dias y fallece no hay camas
# El paciente  7691  en el hospital  A  espero  1  dias y fallece no hay camas
# El paciente  7693  en el hospital  B  espero  1  dias y fallece no hay camas
# El paciente  7698  en el hospital  B  espero  1  dias y fallece no hay camas
# El paciente  7699  en el hospital  B  espero  1  dias y fallece no hay camas
# El paciente  7704  en el hospital  B  espero  1  dias y fallece no hay camas
# El paciente  7708  en el hospital  B  espero  1  dias y fallece no hay camas
# El paciente  7713  en el hospital  B  espero  1  dias y fallece no hay camas
# El paciente  7715  en el hospital  B  espero  1  dias y fallece no hay camas
# El paciente  7717  en el hospital  B  espero  1  dias y fallece no hay camas
# El paciente  7718  en el hospital  A  espero  1  dias y fallece no hay camas
# El paciente  7720  en el hospital  B  espero  1  dias y fallece no hay camas
# El paciente  7721  en el hospital  A  espero  1  dias y fallece no hay camas
# El paciente  7722  en el hospital  A  espero  1  dias y fallece no hay camas
# El paciente  7723  en el hospital  B  espero  1  dias y fallece no hay camas
# El paciente  7726  en el hospital  A  espero  1  dias y fallece no hay camas
# El paciente  7727  en el hospital  A  espero  1  dias y fallece no hay camas
# El paciente  7728  en el hospital  A  espero  1  dias y fallece no hay camas
# El paciente  7733  en el hospital  B  espero  1  dias y fallece no hay camas
# El paciente  7734  en el hospital  A  espero  1  dias y fallece no hay camas
# El paciente  82  en el hospital  A  espero  1  dias y fallece no hubo Equipo
# El paciente  572  en el hospital  A  espero  1  dias y fallece no hubo Equipo
# El paciente  208  en el hospital  A  espero  1  dias y fallece no hubo Equipo
# El paciente  221  en el hospital  A  espero  1  dias y fallece no hubo Equipo
# El paciente  384  en el hospital  A  espero  1  dias y fallece no hubo Equipo
# El paciente  455  en el hospital  A  espero  1  dias y fallece no hubo Equipo
# El paciente  564  en el hospital  A  espero  1  dias y fallece no hubo Equipo
# Al paciente:  71  recive equipos   hospital  B
# Al paciente:  107  recive equipos   hospital  B
# Al paciente:  124  recive equipos   hospital  B
# Al paciente:  243  recive equipos   hospital  B
# Al paciente:  163  recive equipos   hospital  B
# Al paciente:  278  recive equipos   hospital  B
# Al paciente:  6  recive equipos   hospital  B
# Al paciente:  70  recive equipos   hospital  B
# Al paciente:  227  recive equipos   hospital  B
# Al paciente:  237  recive equipos   hospital  B
# Al paciente:  7094  se le asigna una CAMA   hospital  A
# Al paciente:  465  recive equipos   hospital  A
# Al paciente:  7098  se le asigna una CAMA   hospital  A
# Al paciente:  286  recive equipos   hospital  A
# Al paciente:  7116  se le asigna una CAMA   hospital  A
# Al paciente:  336  recive equipos   hospital  A
# Al paciente:  7118  se le asigna una CAMA   hospital  A
# Al paciente:  78  recive equipos   hospital  A
# Al paciente:  7119  se le asigna una CAMA   hospital  A
# Al paciente:  153  recive equipos   hospital  A
# Al paciente:  7129  se le asigna una CAMA   hospital  A
# Al paciente:  201  recive equipos   hospital  A
# Al paciente:  7140  se le asigna una CAMA   hospital  A
# Al paciente:  234  recive equipos   hospital  B
# Al paciente:  7101  se le asigna una CAMA   hospital  B
# Al paciente:  325  recive equipos   hospital  A
# Al paciente:  7143  se le asigna una CAMA   hospital  A
# Al paciente:  57  recive equipos   hospital  B
# Al paciente:  7102  se le asigna una CAMA   hospital  B
# Al paciente:  81  recive equipos   hospital  B
# Al paciente:  7110  se le asigna una CAMA   hospital  B
# Al paciente:  44  recive equipos   hospital  A
# Al paciente:  7144  se le asigna una CAMA   hospital  A
# Al paciente:  69  recive equipos   hospital  A
# Al paciente:  7151  se le asigna una CAMA   hospital  A
# Al paciente:  288  recive equipos   hospital  A
# Al paciente:  7152  se le asigna una CAMA   hospital  A
# Al paciente:  7111  se le asigna una CAMA   hospital  B
# Al paciente:  7113  se le asigna una CAMA   hospital  B
# Al paciente:  7115  se le asigna una CAMA   hospital  B
# Al paciente:  7127  se le asigna una CAMA   hospital  B
# Al paciente:  7128  se le asigna una CAMA   hospital  B
# Al paciente:  7165  se le asigna una CAMA   hospital  A
# Al paciente:  7172  se le asigna una CAMA   hospital  A
# Al paciente:  7190  se le asigna una CAMA   hospital  A
# Al paciente:  7200  se le asigna una CAMA   hospital  A
# Al paciente:  7201  se le asigna una CAMA   hospital  A
# Al paciente:  7205  se le asigna una CAMA   hospital  A
# Al paciente:  7208  se le asigna una CAMA   hospital  A
# Al paciente:  7212  se le asigna una CAMA   hospital  A
# Al paciente:  7220  se le asigna una CAMA   hospital  A
# Al paciente:  7221  se le asigna una CAMA   hospital  A
# Al paciente:  7227  se le asigna una CAMA   hospital  A
# Al paciente:  7233  se le asigna una CAMA   hospital  A
# Al paciente:  7247  se le asigna una CAMA   hospital  A
# Al paciente:  164  recive equipos   hospital  B
# Al paciente:  297  recive equipos   hospital  A
# Al paciente:  368  recive equipos   hospital  A
# Al paciente:  276  recive equipos   hospital  B
# Al paciente:  316  recive equipos   hospital  A
# Al paciente:  393  recive equipos   hospital  A
# Al paciente:  422  recive equipos   hospital  A
# Al paciente:  449  recive equipos   hospital  A
# Al paciente:  592  recive equipos   hospital  A
# Resultados pacientes :
# Recuperados:
# {15: 3, 16: 9, 17: 7, 18: 5, 19: 24}
# Fallecidos:
# {1: 515, 2: 624, 3: 698, 4: 318, 5: 331, 6: 303, 7: 319, 8: 323, 9: 336, 10: 311, 11: 313, 12: 329, 13: 308, 14: 348, 15: 336, 16: 291, 17: 296, 18: 329, 19: 331}

# %% [markdown]
# # Costos

# %%
costo1=(sum(pacientes_atendidos_camas)*(costo_persona-900))
costo2=(sum(pacientes_atendidos_personal)*(costo_persona-500))
costo3=(sum(pacientes_atendidos_equipos)*(costo_persona))
total_costos=(costo1+costo2+costo3)
print("El Total en costo en 20 dias en la Provincia del Pichincha son: ",total_costos)
# Out:
# El Total en costo en 20 dias en la Provincia del Pichincha son:  329000

# %% [markdown]
# ## Conclusiones
#
# podemos decir que la herramienta de simpy es muy efectiva para reaizar este tipo de simulaciones ya que podemos manejar el usp de varias variables o factores y asi poder tener una simulacion mas efectiva
#
# ## Recomendaciones
#
# hacer una investiagion para que esta sea lo mas real posible asi nuestra simulacion esta mucho mas apegada a la realidad y pódremos ser mas serteros en las predcciones que desiemos obtener
#
# ## Opiniones
#
# Con respecto a la informacion es muy evidente que la Provincia a pesar de que es la Capital del Ecuador tiene muchas carencias para atender a la demanda de crecimiento esto segun la simulacion tendra una repercucion muiy grave en la provincia, en resumen no hay equipos necesarios para tneder a todos
